# %% [markdown]
# # Formação Cientista de Dados
# ### Algoritmo Random Forest

# %%
# Importação das bibliotecas
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Carregamento da base de dados e criação dos previsores (variáveis independentes - X) e da classe (variável dependente - y)
credito = pd.read_csv('Credit.csv')
credito.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
previsores = credito.iloc[:,0:20].values
classe = credito.iloc[:,20].values

# %%
# Transformação dos atributos categóricos em atributos numéricos, passando o índice de cada atributo categórico
labelencoder = LabelEncoder()
previsores[:,0] = labelencoder.fit_transform(previsores[:,0])
previsores[:,2] = labelencoder.fit_transform(previsores[:,2])
previsores[:, 3] = labelencoder.fit_transform(previsores[:, 3])
previsores[:, 5] = labelencoder.fit_transform(previsores[:, 5])
previsores[:, 6] = labelencoder.fit_transform(previsores[:, 6])
previsores[:, 8] = labelencoder.fit_transform(previsores[:, 8])
previsores[:, 9] = labelencoder.fit_transform(previsores[:, 9])
previsores[:, 11] = labelencoder.fit_transform(previsores[:, 11])
previsores[:, 13] = labelencoder.fit_transform(previsores[:, 13])
previsores[:, 14] = labelencoder.fit_transform(previsores[:, 14])
previsores[:, 16] = labelencoder.fit_transform(previsores[:, 16])
previsores[:, 18] = labelencoder.fit_transform(previsores[:, 18])
previsores[:, 19] = labelencoder.fit_transform(previsores[:, 19])

# %%
# Divisão da base de dados entre treinamento e teste (30% para testar e 70% para treinar)
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(previsores,
                                                                  classe,
                                                                  test_size = 0.3,
                                                                  random_state = 0)

# %%
# Criação do modelo, treinamento, obtenção das previsões e da taxa de acerto
floresta = RandomForestClassifier(n_estimators = 100)
floresta.fit(X_treinamento, y_treinamento)
# Out:
# RandomForestClassifier()

# %%
# Visualização dos atributos principais
floresta.estimators_
#floresta.estimators_[1]
# Out:
# [DecisionTreeClassifier(max_features='auto', random_state=171312031),
#  DecisionTreeClassifier(max_features='auto', random_state=1496407439),
#  DecisionTreeClassifier(max_features='auto', random_state=435643605),
#  DecisionTreeClassifier(max_features='auto', random_state=925490563),
#  DecisionTreeClassifier(max_features='auto', random_state=1490220328),
#  DecisionTreeClassifier(max_features='auto', random_state=18575624),
#  DecisionTreeClassifier(max_features='auto', random_state=673836439),
#  DecisionTreeClassifier(max_features='auto', random_state=1972783493),
#  DecisionTreeClassifier(max_features='auto', random_state=974348666),
#  DecisionTreeClassifier(max_features='auto', random_state=1799662957),
#  DecisionTreeClassifier(max_features='auto', random_state=785234125),
#  DecisionTreeClassifier(max_features='auto', random_state=994104986),
#  DecisionTreeClassifier(max_features='auto', random_state=729532644),
#  DecisionTreeClassifier(max_features='auto', random_state=650769447),
#  DecisionTreeClassifier(max_features='auto', random_state=2010753093),
#  DecisionTreeClassifier(max_features='auto', random_state=1293182173),
#  DecisionTreeClassifier(max_features='auto', random_state=803377236),
#  DecisionTreeClassifier(max_features='auto', random_state=545960173),
#  DecisionTreeClassifier(max_features='auto', random_state=1453369443),
#  DecisionTreeClassifier(max_features='auto', random_state=769349673),
#  DecisionTreeClassifier(max_features='auto', random_state=2090649313),
#  DecisionTreeClassifier(max_features='auto', random_state=1916549935),
#  DecisionTreeClassifier(max_features='auto', random_state=1633685530),
#  DecisionTreeClassifier(max_features='auto', random_state=1856805547),
#  DecisionTreeClassifier(max_features='auto', random_state=1442030900),
#  DecisionTreeClassifier(max_features='auto', random_state=1038756799),
#  DecisionTreeClassifier(max_features='auto', random_state=823765714),
#  DecisionTreeClassifier(max_features='auto', random_state=339845443),
#  DecisionTreeClassifier(max_features='auto', random_state=1854346132),
#  DecisionTreeClassifier(max_features='auto', random_state=1366131770),
#  DecisionTreeClassifier(max_features='auto', random_state=330918542),
#  DecisionTreeClassifier(max_features='auto', random_state=2116647878),
#  DecisionTreeClassifier(max_features='auto', random_state=805691511),
#  DecisionTreeClassifier(max_features='auto', random_state=1979713023),
#  DecisionTreeClassifier(max_features='auto', random_state=1147949789),
#  DecisionTreeClassifier(max_features='auto', random_state=993504986),
#  DecisionTreeClassifier(max_features='auto', random_state=1223428643),
#  DecisionTreeClassifier(max_features='auto', random_state=1589626076),
#  DecisionTreeClassifier(max_features='auto', random_state=2009667530),
#  DecisionTreeClassifier(max_features='auto', random_state=1203146421),
#  DecisionTreeClassifier(max_features='auto', random_state=1207321535),
#  DecisionTreeClassifier(max_features='auto', random_state=1101639422),
#  DecisionTreeClassifier(max_features='auto', random_state=332703115),
#  DecisionTreeClassifier(max_features='auto', random_state=503141260),
#  DecisionTreeClassifier(max_features='auto', random_state=2089160432),
#  DecisionTreeClassifier(max_features='auto', random_state=948389468),
#  DecisionTreeClassifier(max_features='auto', random_state=447576742),
#  DecisionTreeClassifier(max_features='auto', random_state=345512470),
#  DecisionTreeClassifier(max_features='auto', random_state=609884763),
#  DecisionTreeClassifier(max_features='auto', random_state=504508732),
#  DecisionTreeClassifier(max_features='auto', random_state=1797728736),
#  DecisionTreeClassifier(max_features='auto', random_state=755887475),
#  DecisionTreeClassifier(max_features='auto', random_state=922260908),
#  DecisionTreeClassifier(max_features='auto', random_state=1867105898),
#  DecisionTreeClassifier(max_features='auto', random_state=218997238),
#  DecisionTreeClassifier(max_features='auto', random_state=853185530),
#  DecisionTreeClassifier(max_features='auto', random_state=956261353),
#  DecisionTreeClassifier(max_features='auto', random_state=1449325932),
#  DecisionTreeClassifier(max_features='auto', random_state=357811792),
#  DecisionTreeClassifier(max_features='auto', random_state=309713731),
#  DecisionTreeClassifier(max_features='auto', random_state=2147079786),
#  DecisionTreeClassifier(max_features='auto', random_state=1086948928),
#  DecisionTreeClassifier(max_features='auto', random_state=1026437305),
#  DecisionTreeClassifier(max_features='auto', random_state=1239959577),
#  DecisionTreeClassifier(max_features='auto', random_state=1424118653),
#  DecisionTreeClassifier(max_features='auto', random_state=1578601408),
#  DecisionTreeClassifier(max_features='auto', random_state=1372268387),
#  DecisionTreeClassifier(max_features='auto', random_state=1069735561),
#  DecisionTreeClassifier(max_features='auto', random_state=16074294),
#  DecisionTreeClassifier(max_features='auto', random_state=1002196866),
#  DecisionTreeClassifier(max_features='auto', random_state=1988881712),
#  DecisionTreeClassifier(max_features='auto', random_state=268044135),
#  DecisionTreeClassifier(max_features='auto', random_state=386286292),
#  DecisionTreeClassifier(max_features='auto', random_state=651031657),
#  DecisionTreeClassifier(max_features='auto', random_state=1862499271),
#  DecisionTreeClassifier(max_features='auto', random_state=1303206055),
#  DecisionTreeClassifier(max_features='auto', random_state=455382728),
#  DecisionTreeClassifier(max_features='auto', random_state=670688003),
#  DecisionTreeClassifier(max_features='auto', random_state=1802826780),
#  DecisionTreeClassifier(max_features='auto', random_state=22738778),
#  DecisionTreeClassifier(max_features='auto', random_state=2062506744),
#  DecisionTreeClassifier(max_features='auto', random_state=1919678473),
#  DecisionTreeClassifier(max_features='auto', random_state=2091369473),
#  DecisionTreeClassifier(max_features='auto', random_state=1445431065),
#  DecisionTreeClassifier(max_features='auto', random_state=1801013108),
#  DecisionTreeClassifier(max_features='auto', random_state=1340748608),
#  DecisionTreeClassifier(max_features='auto', random_state=1440741198),
#  DecisionTreeClassifier(max_features='auto', random_state=1353354213),
#  DecisionTreeClassifier(max_features='auto', random_state=1255494206),
#  DecisionTreeClassifier(max_features='auto', random_state=655681593),
#  DecisionTreeClassifier(max_features='auto', random_state=1929169865),
#  DecisionTreeClassifier(max_features='auto', random_state=596803264),
#  DecisionTreeClassifier(max_features='auto', random_state=569214212),
#  DecisionTreeClassifier(max_features='auto', random_state=100095254),
#  DecisionTreeClassifier(max_features='auto', random_state=829065708),
#  DecisionTreeClassifier(max_features='auto', random_state=535781202),
#  DecisionTreeClassifier(max_features='auto', random_state=1931719600),
#  DecisionTreeClassifier(max_features='auto', random_state=29974033),
#  DecisionTreeClassifier(max_features='auto', random_state=1019700023),
#  DecisionTreeClassifier(max_features='auto', random_state=1945791829)]

# %%
previsoes = floresta.predict(X_teste)
confusao = confusion_matrix(y_teste, previsoes)
taxa_acerto = accuracy_score(y_teste, previsoes)
taxa_acerto
# Out:
# 0.7766666666666666
